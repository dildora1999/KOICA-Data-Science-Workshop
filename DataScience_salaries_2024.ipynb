# %%
import pandas as pd
import numpy as np

ds_data = pd.read_csv("DataScience_salaries_2024.csv")
ds_data.head(10)
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021               MI              FT                  Data Scientist
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI              FT                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
# 5       2021               MI              FT                     ML Engineer
# 6       2021               SE              FT            Data Science Manager
# 7       2022               EN              FT                  Data Scientist
# 8       2022               EX              FT        Head of Machine Learning
# 9       2022               EN              FT               Research Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
ds_data2 = ds_data[ds_data["salary_in_usd"] >=70000 ]
ds_data2.head(10)
# Out:
#     work_year experience_level employment_type  \
# 3        2021               MI              FT
# 4        2022               SE              FT
# 6        2021               SE              FT
# 8        2022               EX              FT
# 46       2023               SE              FT
# 62       2023               EX              FT
# 66       2024               MI              FT
# 67       2023               SE              FT
# 68       2024               EN              FT
# 69       2024               SE              FT
#
#                          job_title   salary salary_currency  salary_in_usd  \
# 3                      ML Engineer  8500000             JPY          77364
# 4   Lead Machine Learning Engineer  7500000             INR          95386
# 6             Data Science Manager  7000000             INR          94665
# 8         Head of Machine Learning  6000000             INR          76309
# ...

# %%
ds_data2.sort_values(by='salary_in_usd', ascending=True)
# Out:
#        work_year experience_level employment_type  \
# 14003       2024               SE              FT
# 13419       2023               SE              FT
# 13418       2023               MI              FT
# 13416       2023               SE              FT
# 13415       2023               EX              FT
# ...          ...              ...             ...
# 69          2024               SE              FT
# 76          2023               SE              FT
# 73          2023               MI              FT
# 68          2024               EN              FT
# 66          2024               MI              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# 14003               Data Scientist   56000             GBP          70000
# 13419                 Data Analyst   70000             USD          70000
# 13418  Machine Learning Specialist   70000             USD          70000
# ...

# %%
print("Average salary by job title table\n")
average_salary_by_job_title = df.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=True)

pd.set_option('display.max_rows', None)
print(average_salary_by_job_title)
# Out:
# Average salary by job title table
#
# job_title
# Principal Data Architect                     38154.000000
# CRM Data Analyst                             40000.000000
# Compliance Data Analyst                      45000.000000
# Insight Analyst                              46459.916667
# Admin & Data Analyst                         50740.666667
# Quantitative Research Analyst                51000.000000
# Machine Learning Specialist                  55000.000000
# Encounter Data Management Professional       56650.000000
# Data Quality Manager                         59059.000000
# BI Data Engineer                             60000.000000
# Sales Data Analyst                           60000.000000
# Data Operations Associate                    61399.000000
# AI Programmer                                62042.000000
# Power BI Developer                           64781.000000
# Data DevOps Engineer                         65638.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
top_countries = ds_data['employee_residence'].value_counts().head(10).index
sns.boxplot(data=ds_data[ds_data['employee_residence'].isin(top_countries)], x='salary_in_usd', y='employee_residence')
plt.title('Salary Distribution in USD by Country of Residence (Top 10)')
plt.xlabel('Country of Residence')
plt.ylabel('Salary (USD)')
plt.xticks(rotation=45)
plt.show()
